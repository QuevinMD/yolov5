# %% [markdown]
# <a href="https://colab.research.google.com/github/QuevinMD/yolov5/blob/master/YoloV5Projeto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-213-g378ed74 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
# !unzip -q /content/imagens.zip -d /content/yolov5/data

# %%
# !python /content/yolov5/train.py --img 640 --batch 20 --epochs 50 --data coco128.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=20, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-213-g378ed74 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python detect.py --weights yolov5s.pt --source /content/apple-tree-care-apples-on-branch.jpg
# Out:
# detect: weights=['yolov5s.pt'], source=/content/apple-tree-care-apples-on-branch.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-213-g378ed74 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# apple: 3
# image 1/1 /content/apple-tree-care-apples-on-branch.jpg: 640x512 3 apples, 45.5ms
# Speed: 0.5ms pre-process, 45.5ms inference, 83.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5

# %%
# !python detect.py --weights yolov5s.pt --source /content/VID.mp4
# Out:
# detect: weights=['yolov5s.pt'], source=/content/VID.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-213-g378ed74 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# bowl: 1
# apple: 1
# video 1/1 (1/292) /content/VID.mp4: 640x384 1 bowl, 1 apple, 1 bowl, 1 apple, 46.4ms
# bowl: 1
# apple: 1
# video 1/1 (2/292) /content/VID.mp4: 640x384 1 bowl, 1 apple, 1 bowl, 1 apple, 8.2ms
# bowl: 1
# apple: 1
# video 1/1 (3/292) /content/VID.mp4: 640x384 1 bowl, 1 apple, 1 bowl, 1 apple, 9.0ms
# bowl: 1
# apple: 1
# ...

# %%
!  git config --global user.email "kevindomingos97@gmail.com"
! git add .
! git commit -m "Projeto II"
! git push origin master
# Out:
# [main 8d3963f] Projeto II
#  6 files changed, 63 insertions(+), 103 deletions(-)
#  create mode 100644 .cometml-runs/468aa23bf0b3449b8ac8b04f5d5bf1c5.zip
#  create mode 100644 .cometml-runs/83c9978614c7423b9de53bf0388c5833.zip
#  rewrite data/coco128.yaml (98%)
#  delete mode 100644 data/images/bus.jpg
#  delete mode 100644 data/images/zidane.jpg
# error: src refspec master does not match any
# error: failed to push some refs to 'https://github.com/ultralytics/yolov5'
